# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
diff = []
for i in range(0,10):
    
    data = np.loadtxt('../ila_data/iladata_0%i.csv' %(i), skiprows=2, delimiter=',')
    sample = data[:,0]
    diff.extend(data[:,7])

bins=np.arange(-2.5,3, 1)
print(bins)
plt.hist(diff, bins, density=True)
diff = np.array(diff)
print(len(np.argwhere(diff==2)))
print(100 - 32/len(diff)*100)
# Out:
# [-2.5 -1.5 -0.5  0.5  1.5  2.5]
# 32
# 99.6875

# %%
print(3/np.std(diff))
# Out:
# 5.898015743019936
